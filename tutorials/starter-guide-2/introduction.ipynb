# %% [markdown]
# # 🐣 Starter guide
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/your-repo/zenml-docs/blob/main/notebooks/01_introduction.ipynb) [![Run Locally](https://img.shields.io/badge/run-locally-blue)](https://github.com/your-repo/zenml-docs)
#
# Welcome to the ZenML Starter Guide! If you're an MLOps engineer aiming to build robust ML platforms, or a data scientist interested in leveraging the power of MLOps, this is the perfect place to begin. Our guide is designed to provide you with the foundational knowledge of the ZenML framework and equip you with the initial tools to manage the complexity of machine learning operations.
#
# ![Embarking on MLOps can be intricate. ZenML simplifies the journey.](../../docs/book/.gitbook/assets/01_pipeline.png)
#
# Throughout this guide, we'll cover essential topics including:
#
# - Creating your first ML pipeline
# - Understanding caching between pipeline steps
# - Fetching objects after pipelines have run
# - Managing data and data versioning
# - Tracking your machine learning models
# - Structuring your pipelines, models, and artifacts
#
# Before jumping in, make sure you have a Python environment ready and `virtualenv` installed to follow along with ease.

# %%
# !pip install zenml

# %% [markdown]
# By the end, you will have completed a starter project, marking the beginning of your journey into MLOps with ZenML.
#
# Let this guide be not only your introduction to ZenML but also a foundational asset in your MLOps toolkit. Prepare your development environment, and let's get started!

# %%
from zenml import pipeline, step

@step
def load_data() -> dict:
    """Simulates loading of training data and labels."""

    training_data = [[1, 2], [3, 4], [5, 6]]
    labels = [0, 1, 0]
    
    return {'features': training_data, 'labels': labels}

@step
def train_model(data: dict) -> None:
    """
    A mock 'training' process that also demonstrates using the input data.
    In a real-world scenario, this would be replaced with actual model fitting logic.
    """
    total_features = sum(map(sum, data['features']))
    total_labels = sum(data['labels'])
    
    print(f"Trained model using {len(data['features'])} data points. "
          f"Feature sum is {total_features}, label sum is {total_labels}")

@pipeline
def simple_ml_pipeline():
    """Define a pipeline that connects the steps."""
    dataset = load_data()
    train_model(dataset)

if __name__ == "__main__":
    run = simple_ml_pipeline()
    # You can now use the `run` object to see steps, outputs, etc.

# %% [markdown]
# {% hint style="info" %}
# * **`@step`** is a decorator that converts its function into a step that can be used within a pipeline
# * **`@pipeline`** defines a function as a pipeline and within this function, the steps are called and their outputs link them together.
# {% endhint %}
#
# Copy this code into a new file and name it `run.py`. Then run it with your command line:

# %%
from zenml import pipeline, step

@step
def load_data() -> dict:
    """Simulates loading of training data and labels."""

    training_data = [[1, 2], [3, 4], [5, 6]]
    labels = [0, 1, 0]
    
    return {'features': training_data, 'labels': labels}

@step
def train_model(data: dict) -> None:
    """
    A mock 'training' process that also demonstrates using the input data.
    In a real-world scenario, this would be replaced with actual model fitting logic.
    """
    total_features = sum(map(sum, data['features']))
    total_labels = sum(data['labels'])
    
    print(f"Trained model using {len(data['features'])} data points. "
          f"Feature sum is {total_features}, label sum is {total_labels}")

@pipeline
def simple_ml_pipeline():
    """Define a pipeline that connects the steps."""
    dataset = load_data()
    train_model(dataset)

if __name__ == "__main__":
    run = simple_ml_pipeline()
    # You can now use the `run` object to see steps, outputs, etc.
# Out:
# /Users/htahir1/Envs/zenml_development/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Initiating a new run for the pipeline: simple_ml_pipeline.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /Users/htahir1/Workspace/zenml/src/zenml/zen_stores/rest_zen_store.py:4186 in _request           │
# │                                                                                                  │
# │   4183 │   │   )                                                                                 │
# │   4184 │   │                                                                                     │
# │   4185 │   │   try:                                                                              │
# │ ❱ 4186 │   │   │   return self._handle_response(                                                 │
# │   4187 │   │   │   │   self.session.request(                                                     │
# │   4188 │   │   │   │   │   method,                                                               │
# │   4189 │   │   │   │   │   url,                                                                  │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/zen_stores/rest_zen_store.py:4143 in _handle_response   │
# │                                                                                                  │
# │   4140 │   │   elif response.status_code >= 400:                                                 │
# │   4141 │   │   │   exc = exception_from_response(response)                                       │
# │   4142 │   │   │   if exc is not None:                                                           │
# │ ❱ 4143 │   │   │   │   raise exc                                                                 │
# │   4144 │   │   │   else:                                                                         │
# │   4145 │   │   │   │   raise RuntimeError(                                                       │
# │   4146 │   │   │   │   │   f"{response.status_code} HTTP Error received from server: "           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AuthorizationException: Authentication error: error decoding access token: Invalid JWT token: Signature
# verification failed.
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:31                                                                                   │
# │                                                                                                  │
# │   28 │   train_model(dataset)                                                                    │
# │   29                                                                                             │
# │   30 if __name__ == "__main__":                                                                  │
# │ ❱ 31 │   run = simple_ml_pipeline()                                                              │
# │   32 │   # You can now use the `run` object to see steps, outputs, etc.                          │
# │   33                                                                                             │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/new/pipelines/pipeline.py:1378 in __call__              │
# │                                                                                                  │
# │   1375 │   │   │   return self.entrypoint(*args, **kwargs)                                       │
# │   1376 │   │                                                                                     │
# │   1377 │   │   self.prepare(*args, **kwargs)                                                     │
# │ ❱ 1378 │   │   return self._run(**self._run_args)                                                │
# │   1379 │                                                                                         │
# │   1380 │   def _call_entrypoint(self, *args: Any, **kwargs: Any) -> None:                        │
# │   1381 │   │   """Calls the pipeline entrypoint function with the given arguments.               │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/new/pipelines/pipeline.py:607 in _run                   │
# │                                                                                                  │
# │    604 │   │   logger.info(f"Initiating a new run for the pipeline: `{self.name}`.")             │
# │    605 │   │                                                                                     │
# │    606 │   │   with track_handler(AnalyticsEvent.RUN_PIPELINE) as analytics_handler:             │
# │ ❱  607 │   │   │   deployment, schedule, build = self._compile(                                  │
# │    608 │   │   │   │   config_path=config_path,                                                  │
# │    609 │   │   │   │   run_name=run_name,                                                        │
# │    610 │   │   │   │   enable_cache=enable_cache,                                                │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/new/pipelines/pipeline.py:1027 in _compile              │
# │                                                                                                  │
# │   1024 │   │                                                                                     │
# │   1025 │   │   deployment = Compiler().compile(                                                  │
# │   1026 │   │   │   pipeline=self,                                                                │
# │ ❱ 1027 │   │   │   stack=Client().active_stack,                                                  │
# │   1028 │   │   │   run_configuration=run_config,                                                 │
# │   1029 │   │   )                                                                                 │
# │   1030                                                                                           │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/client.py:1447 in active_stack                          │
# │                                                                                                  │
# │   1444 │   │   """                                                                               │
# │   1445 │   │   from zenml.stack.stack import Stack                                               │
# │   1446 │   │                                                                                     │
# │ ❱ 1447 │   │   return Stack.from_model(self.active_stack_model)                                  │
# │   1448 │                                                                                         │
# │   1449 │   @property                                                                             │
# │   1450 │   def active_stack_model(self) -> StackResponse:                                        │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/client.py:1476 in active_stack_model                    │
# │                                                                                                  │
# │   1473 │   │   if not stack_id:                                                                  │
# │   1474 │   │   │   # Initialize the zen store so the global config loads the active              │
# │   1475 │   │   │   # stack                                                                       │
# │ ❱ 1476 │   │   │   _ = GlobalConfiguration().zen_store                                           │
# │   1477 │   │   │   if active_stack := GlobalConfiguration()._active_stack:                       │
# │   1478 │   │   │   │   return active_stack                                                       │
# │   1479                                                                                           │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/config/global_config.py:230 in __custom_getattribute__  │
# │                                                                                                  │
# │   227 │   │   Returns:                                                                           │
# │   228 │   │   │   The attribute value.                                                           │
# │   229 │   │   """                                                                                │
# │ ❱ 230 │   │   value = super().__getattribute__(key)                                              │
# │   231 │   │   if key.startswith("_") or key not in type(self).model_fields:                      │
# │   232 │   │   │   return value                                                                   │
# │   233                                                                                            │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/config/global_config.py:703 in zen_store                │
# │                                                                                                  │
# │   700 │   │   │   The current zen store.                                                         │
# │   701 │   │   """                                                                                │
# │   702 │   │   if self._zen_store is None:                                                        │
# │ ❱ 703 │   │   │   self._configure_store(self.store_configuration)                                │
# │   704 │   │   assert self._zen_store is not None                                                 │
# │   705 │   │                                                                                      │
# │   706 │   │   return self._zen_store                                                             │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/config/global_config.py:379 in _configure_store         │
# │                                                                                                  │
# │   376 │   │   │   store._initialize_database()                                                   │
# │   377 │   │                                                                                      │
# │   378 │   │   # Sanitize the global configuration to reflect the new store                       │
# │ ❱ 379 │   │   self._sanitize_config()                                                            │
# │   380 │   │   self._write_config()                                                               │
# │   381 │   │                                                                                      │
# │   382 │   │   local_stores_path = Path(self.local_stores_path)                                   │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/config/global_config.py:395 in _sanitize_config         │
# │                                                                                                  │
# │   392 │   │   # workspace are not relevant                                                       │
# │   393 │   │   if ENV_ZENML_SERVER in os.environ:                                                 │
# │   394 │   │   │   return                                                                         │
# │ ❱ 395 │   │   active_workspace, active_stack = self.zen_store.validate_active_config(            │
# │   396 │   │   │   self.active_workspace_name,                                                    │
# │   397 │   │   │   self.active_stack_id,                                                          │
# │   398 │   │   │   config_name="global",                                                          │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/zen_stores/base_zen_store.py:357 in                     │
# │ validate_active_config                                                                           │
# │                                                                                                  │
# │   354 │   │                                                                                      │
# │   355 │   │   if active_workspace_name_or_id:                                                    │
# │   356 │   │   │   try:                                                                           │
# │ ❱ 357 │   │   │   │   active_workspace = self.get_workspace(                                     │
# │   358 │   │   │   │   │   active_workspace_name_or_id                                            │
# │   359 │   │   │   │   )                                                                          │
# │   360 │   │   │   except KeyError:                                                               │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/zen_stores/rest_zen_store.py:3394 in get_workspace      │
# │                                                                                                  │
# │   3391 │   │   Returns:                                                                          │
# │   3392 │   │   │   The requested workspace.                                                      │
# │   3393 │   │   """                                                                               │
# │ ❱ 3394 │   │   return self._get_resource(                                                        │
# │   3395 │   │   │   resource_id=workspace_name_or_id,                                             │
# │   3396 │   │   │   route=WORKSPACES,                                                             │
# │   3397 │   │   │   response_model=WorkspaceResponse,                                             │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/zen_stores/rest_zen_store.py:4481 in _get_resource      │
# │                                                                                                  │
# │   4478 │   │   Returns:                                                                          │
# │   4479 │   │   │   The retrieved resource.                                                       │
# │   4480 │   │   """                                                                               │
# │ ❱ 4481 │   │   body = self.get(f"{route}/{str(resource_id)}", params=params)                     │
# │   4482 │   │   return response_model.model_validate(body)                                        │
# │   4483 │                                                                                         │
# │   4484 │   def _list_paginated_resources(                                                        │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/zen_stores/rest_zen_store.py:4239 in get                │
# │                                                                                                  │
# │   4236 │   │   │   The response body.                                                            │
# │   4237 │   │   """                                                                               │
# │   4238 │   │   logger.debug(f"Sending GET request to {path}...")                                 │
# │ ❱ 4239 │   │   return self._request(                                                             │
# │   4240 │   │   │   "GET",                                                                        │
# │   4241 │   │   │   self.url + API + VERSION_1 + path,                                            │
# │   4242 │   │   │   params=params,                                                                │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/zen_stores/rest_zen_store.py:4200 in _request           │
# │                                                                                                  │
# │   4197 │   │   │   # The authentication token could have expired; refresh it and try             │
# │   4198 │   │   │   # again. This will clear any cached token and trigger a new                   │
# │   4199 │   │   │   # authentication flow.                                                        │
# │ ❱ 4200 │   │   │   self.clear_session()                                                          │
# │   4201 │   │   │   logger.info("Authentication token expired; refreshing...")                    │
# │   4202 │   │                                                                                     │
# │   4203 │   │   try:                                                                              │
# │                                                                                                  │
# │ /Users/htahir1/Workspace/zenml/src/zenml/zen_stores/rest_zen_store.py:4104 in clear_session      │
# │                                                                                                  │
# │   4101 │   │   ):                                                                                │
# │   4102 │   │   │   self.config.api_token = None                                                  │
# │   4103 │   │   elif self.config.api_token:                                                       │
# │ ❱ 4104 │   │   │   raise AuthorizationException(                                                 │
# │   4105 │   │   │   │   "Unable to refresh invalid API token. This is probably "                  │
# │   4106 │   │   │   │   "because you're connected to your ZenML server with device "              │
# │   4107 │   │   │   │   "authentication. Rerunning `zenml connect --url "                         │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AuthorizationException: Unable to refresh invalid API token. This is probably because you're connected to your
# ZenML server with device authentication. Rerunning `zenml connect --url https://1cf18d95-zenml.cloudinfra.zenml.io`
# should solve this issue. If you're seeing this error from an automated workload, you should probably use a service
# account to start that workload to prevent this error.
