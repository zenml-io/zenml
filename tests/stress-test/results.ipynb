# %% [markdown]
# # Stress Test Results

# %%
from utils import LogFile

# %%
log_file = LogFile.parse_logs("zenml-logs-json.txt")

# %%
# list(log_file.request_flows.values())[0][0].display()

# %%
log_file.plot_request_flows(
    start_time=200,
    end_time=500,
    max_requests=200,
    # pps=10,
    # width=2000,
    height=1000,
    width=1900,
    # pod=1,
    hide_legend=True,
    hide_y_axis=True,
    # api_call_filter=[
    #     ".*/api/v1/service_connectors/<uuid>/client",
    #     ".*/api/v1/runs$",
    #     ".*/api/v1/pipeline_deployments",
    # ],
    min_duration=2,
    # group_retry_requests=False,
    # filter_states=[LogType.SQL_STARTED, LogType.SQL_COMPLETED],
    # request_id="88ddf46e",
)

# %%
log_file.plot(
    log_file.get_plot_fn(
        y_metric="threads",
        # y_metric="memory_usage",
        # y_metric="active_requests",
        label_attribute="pod",
    ),
)
